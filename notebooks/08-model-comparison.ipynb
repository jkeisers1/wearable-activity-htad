# %%
import pandas as pd
from pathlib import Path

df_audio = pd.read_csv("outputs/audio_metrics.csv")
df_accel = pd.read_csv("outputs/acc_metrics.csv")
df_fusion = pd.read_csv("outputs/fusion_metrics.csv")

results_df = pd.concat([df_audio, df_accel, df_fusion], ignore_index=True)
display(results_df)
# Out:
#           Model  Accuracy  F1 Macro  F1 Weighted
# 0   Audio Model  0.805755  0.799122     0.802267
# 1     Acc Model  0.877637  0.872699     0.878824
# 2  Fusion Model  0.936709  0.934903     0.936201
